# %% [markdown]
# <a href="https://colab.research.google.com/github/rijal0708/data-science-2026/blob/main/Pertemuan1_M_Rijal_Anshory_DJ_240401010281.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Output Sederhana

# %%
print('Hello, Data Science!')
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# Variabel dan tipe data dasar

# %%
nama = "M Rijal Anshory DJ" # String
angkatan = 2024 # Integer
ipk = 3.98 # Float
aktif = True # Boolean
prodi = "Informatika" # String

print(f'Halo, {nama} angkatan {angkatan} dengan ipk {ipk} dari prodi {prodi} dengan status aktif {aktif} ' )
# Out:
# Halo, M Rijal Anshory DJ angkatan 2024 dengan ipk 3.98 dari prodi Informatika dengan status aktif True

# %% [markdown]
# List dan perulangan

# %%
tools = ["Python", "Google Colap", "Jupyter Notebook", "Github"]

print("\n Tool dan Data Science yang akan kita pelajari adalah : ")

for i , tools in enumerate(tools, 1):
  print(f"{i} . {tools}")
# Out:
#  Tool dan Data Science yang akan kita pelajari adalah :
# 1 . Python
# 2 . Google Colap
# 3 . Jupyter Notebook
# 4 . Github

# %% [markdown]
# Fungsi Python

# %%
def perkenalan(nama, prodi, angkatan ):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("M Rijal Anshory DJ", "Informatika", 2024))
# Out:
# M Rijal Anshory DJ | Informatika | 2024
